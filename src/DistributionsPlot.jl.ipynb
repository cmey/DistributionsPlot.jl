# %% [markdown]
# # Plot each distribution of the [Distributions.jl package](http://distributionsjl.readthedocs.io).
#
# #### TODO:
#  * introspect args and do a plot per multiple values (probably just 0, 0.5 and 1) per arg
#  * find normalization factor of distribution (the multiplicative factor that ensures that the area under the density—the probability of something in the domain occurring— equals 1). This normalization factor is outside the kernel of the distribution.
#  * generate an HTML file cleaned from Jupyter clutter
#  * import markdown from README.md instead of duplicate header

# %%
# Pkg.add("Distributions")
# Pkg.add("GR")
# Pkg.add("Plots")
# Pkg.add("StatPlots")

# %%
using Distributions

# %%
# Get list of distributions from exported functions from module Distributions.
d_names = names(Distributions)
# Every module has a function named `eval` - let's filter that out.
d_names = filter(x -> x != "eval", d_names)
# Heuristic: Distribution functions all start with a capital letter.
startsWithCapital(s) = ismatch(r"^[A-Z].*$", string(s))
d_names = filter(s -> startsWithCapital(s), d_names);
print("$(length(d_names)) functions were found.")
# Out:
# 122 functions were found.

# %%
using Plots
# pyplot()
gr()
using StatPlots
# Out:
# INFO: Recompiling stale cache file /Users/cmey/.julia/lib/v0.6/DataFrames.ji for module DataFrames.
# INFO: Recompiling stale cache file /Users/cmey/.julia/lib/v0.6/TableTraits.ji for module TableTraits.
# INFO: Recompiling stale cache file /Users/cmey/.julia/lib/v0.6/IterableTables.ji for module IterableTables.
# INFO: Recompiling stale cache file /Users/cmey/.julia/lib/v0.6/DataValues.ji for module DataValues.
# INFO: Precompiling module TableTraitsUtils.
# INFO: Recompiling stale cache file /Users/cmey/.julia/lib/v0.6/DiffResults.ji for module DiffResults.
# INFO: Recompiling stale cache file /Users/cmey/.julia/lib/v0.6/KernelDensity.ji for module KernelDensity.
# WARNING: StatsBase.WeightVec is deprecated, use StatsBase.Weights{#1#S, #2#T, #3#V} where #3#V<:AbstractArray{#2#T, 1} where #2#T<:Real where #1#S<:Real instead.
#   likely near /Users/cmey/.julia/v0.6/KernelDensity/src/univariate.jl:80
# INFO: Recompiling stale cache file /Users/cmey/.julia/lib/v0.6/Loess.ji for module Loess.

# %%
# Generate a list where each entry tells how many arguments to pass to the ctor.
function list_num_args_in_ctors(d)
    d_method = getfield(Distributions, d)
    num_args_in_ctors = []
    for method in methods(d_method)
    #     println(method)
        r = Regex("^.*" * string(d) * ".*\\((.*)\\).*\$")
    #     println(r)
        m = match(r, string(method))
        if nothing == m
            continue
        end
    #     println(m.captures)
        @assert 1 == length(m.captures)
        c = m.captures[1]
        L = length(filter(x -> !isempty(x), split(c, ',')))
        push!(num_args_in_ctors, L)
    end
    return sort(unique(num_args_in_ctors))
end
# Demo:
println(methods(Distributions.Normal))
list_num_args_in_ctors(:Normal)
# Out:
# # 6 methods for generic function "(::Type)":
# (::Type{Distributions.Normal})() in Distributions at /Users/cmey/.julia/v0.6/Distributions/src/univariate/continuous/normal.jl:38
# (::Type{Distributions.Normal})(μ::Integer, σ::Integer) in Distributions at /Users/cmey/.julia/v0.6/Distributions/src/univariate/continuous/normal.jl:36
# (::Type{Distributions.Normal})(μ::Real) in Distributions at /Users/cmey/.julia/v0.6/Distributions/src/univariate/continuous/normal.jl:37
# (::Type{Distributions.Normal})(μ::T, σ::T) where T<:Real in Distributions at /Users/cmey/.julia/v0.6/Distributions/src/univariate/continuous/normal.jl:34
# (::Type{Distributions.Normal})(μ::Real, σ::Real) in Distributions at /Users/cmey/.julia/v0.6/Distributions/src/univariate/continuous/normal.jl:35
# (::Type{T})(arg) where T in Base at sysimg.jl:77
# 3-element Array{Int64,1}:
#  0
#  1
#  2

# %%
for d in d_names
    method_name = ""
    d_obj = nothing
    d_obj1 = nothing
    d_obj2 = nothing
    
    try
        method_name = getfield(Distributions, d)
    catch err
        println("Could not access $method_name (method exposed but not implemented): $err.")
        try
            println("$(err.msg).")
        end
        continue
    end
    
    L = list_num_args_in_ctors(d)
    if 0 in L
        try
            d_obj = method_name()
        catch err
            println("Could not create a default $method_name: $err.")
            try
                println("$(err.msg).")
            end
            continue
        end
    end
    if 1 in L
        try
            d_obj1 = method_name(1)
        catch err
            println("Could not create $method_name (1): $err.")
            try
                println("$(err.msg).")
            end
            continue
        end
    end
    if 2 in L
        try
            d_obj2 = method_name(1, 1)
        catch err
            println("Could not create $method_name (1, 1): $err.")
            try
                println("$(err.msg).")
            end
            continue
        end
    end
    
    try
        p = plot(d_obj,
            title="Probability density function of\n" * string(method_name),
            xlabel="value of random variable",
            ylabel="probability",
            label="$d()",
        )
        if 1 in L
            try
                plot!(d_obj1)
            catch err1
                println("Could not plot $method_name (1): $err1.")
                try
                    println("$(err1.msg).")
                end
            end
        end
        if 2 in L
            try
                plot!(d_obj2)
            catch err2
                println("Could not plot $method_name (1, 1): $err2.")
                try
                    println("$(err2.msg).")
                end
            end
        end
        display(p)
    catch err
        println("Could not plot the default $method_name: $err.")
        try
            println("$(err.msg).")
        end
        continue
    end
end
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip8200)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip8200)" points="
# 47.9701,360.065 580.315,360.065 580.315,31.4961 47.9701,31.4961
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip02">
#     <rect x="47" y="31" width="533" height="330"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip8202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   151.569,355.137 151.569,36.4246
#   "/>
# <polyline clip-path="url(#clip8202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   260.486,355.137 260.486,36.4246
#   "/>
# <polyline clip-path="url(#clip8202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   369.402,355.137 369.402,36.4246
#   "/>
# <polyline clip-path="url(#clip8202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   478.319,355.137 478.319,36.4246
#   "/>
# <polyline clip-path="url(#clip8202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   55.9553,360.065 572.33,360.065
#   "/>
# <polyline clip-path="url(#clip8202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   55.9553,294.352 572.33,294.352
#   "/>
# <polyline clip-path="url(#clip8202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   55.9553,228.638 572.33,228.638
#   "/>
# <polyline clip-path="url(#clip8202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   55.9553,162.924 572.33,162.924
#   "/>
# <polyline clip-path="url(#clip8202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   55.9553,97.2099 572.33,97.2099
#   "/>
# <polyline clip-path="url(#clip8202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   55.9553,31.4961 572.33,31.4961
#   "/>
# <polyline clip-path="url(#clip8200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   47.9701,360.065 580.315,360.065
#   "/>
# <polyline clip-path="url(#clip8200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   47.9701,360.065 47.9701,31.4961
#   "/>
# <polyline clip-path="url(#clip8200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   151.569,360.065 151.569,355.137
#   "/>
# <polyline clip-path="url(#clip8200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   260.486,360.065 260.486,355.137
#   "/>
# <polyline clip-path="url(#clip8200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   369.402,360.065 369.402,355.137
#   "/>
# <polyline clip-path="url(#clip8200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   478.319,360.065 478.319,355.137
#   "/>
# <polyline clip-path="url(#clip8200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   47.9701,360.065 55.9553,360.065
#   "/>
# <polyline clip-path="url(#clip8200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   47.9701,294.352 55.9553,294.352
#   "/>
# <polyline clip-path="url(#clip8200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   47.9701,228.638 55.9553,228.638
#   "/>
# <polyline clip-path="url(#clip8200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   47.9701,162.924 55.9553,162.924
#   "/>
# <polyline clip-path="url(#clip8200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   47.9701,97.2099 55.9553,97.2099
#   "/>
# <polyline clip-path="url(#clip8200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   47.9701,31.4961 55.9553,31.4961
#   "/>
# <g clip-path="url(#clip8200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 151.569, 373.865)" x="151.569" y="373.865">0.2</text>
# </g>
# <g clip-path="url(#clip8200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 260.486, 373.865)" x="260.486" y="373.865">0.4</text>
# </g>
# <g clip-path="url(#clip8200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 369.402, 373.865)" x="369.402" y="373.865">0.6</text>
# </g>
# <g clip-path="url(#clip8200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 478.319, 373.865)" x="478.319" y="373.865">0.8</text>
# </g>
# <g clip-path="url(#clip8200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 41.9701, 364.565)" x="41.9701" y="364.565">0.0</text>
# </g>
# <g clip-path="url(#clip8200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 41.9701, 298.852)" x="41.9701" y="298.852">0.2</text>
# </g>
# <g clip-path="url(#clip8200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 41.9701, 233.138)" x="41.9701" y="233.138">0.4</text>
# </g>
# <g clip-path="url(#clip8200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 41.9701, 167.424)" x="41.9701" y="167.424">0.6</text>
# </g>
# <g clip-path="url(#clip8200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 41.9701, 101.71)" x="41.9701" y="101.71">0.8</text>
# </g>
# <g clip-path="url(#clip8200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 41.9701, 35.9961)" x="41.9701" y="35.9961">1.0</text>
# </g>
# <g clip-path="url(#clip8200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:21; text-anchor:middle;" transform="rotate(0, 314.143, 18)" x="314.143" y="18">Probability density function of</text>
# </g>
# <g clip-path="url(#clip8200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:21; text-anchor:middle;" transform="rotate(0, 314.143, 40.68)" x="314.143" y="40.68">Distributions.Bernoulli</text>
# </g>
# <g clip-path="url(#clip8200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:16; text-anchor:middle;" transform="rotate(0, 314.143, 397.6)" x="314.143" y="397.6">value of random variable</text>
# </g>
# <g clip-path="url(#clip8200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:16; text-anchor:middle;" transform="rotate(-90, 14.4, 195.781)" x="14.4" y="195.781">probability</text>
# </g>
# <polyline clip-path="url(#clip8202)" style="stroke:#009af9; stroke-width:1; stroke-opacity:1; fill:none" points="
#   47.9701,360.065 97.1456,360.065
#   "/>
# <polyline clip-path="url(#clip8202)" style="stroke:#009af9; stroke-width:1; stroke-opacity:1; fill:none" points="
#   97.1456,360.065 126.698,360.065
#   "/>
# <polyline clip-path="url(#clip8202)" style="stroke:#009a
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip8400)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip8400)" points="
# 54.5598,360.065 580.315,360.065 580.315,31.4961 54.5598,31.4961
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip02">
#     <rect x="54" y="31" width="527" height="330"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip8402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   156.876,355.137 156.876,36.4246
#   "/>
# <polyline clip-path="url(#clip8402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   264.445,355.137 264.445,36.4246
#   "/>
# <polyline clip-path="url(#clip8402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   372.013,355.137 372.013,36.4246
#   "/>
# <polyline clip-path="url(#clip8402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   479.582,355.137 479.582,36.4246
#   "/>
# <polyline clip-path="url(#clip8402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   62.4461,360.065 572.429,360.065
#   "/>
# <polyline clip-path="url(#clip8402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   62.4461,277.923 572.429,277.923
#   "/>
# <polyline clip-path="url(#clip8402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   62.4461,195.781 572.429,195.781
#   "/>
# <polyline clip-path="url(#clip8402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   62.4461,113.638 572.429,113.638
#   "/>
# <polyline clip-path="url(#clip8402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   62.4461,31.4961 572.429,31.4961
#   "/>
# <polyline clip-path="url(#clip8400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   54.5598,360.065 580.315,360.065
#   "/>
# <polyline clip-path="url(#clip8400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   54.5598,360.065 54.5598,31.4961
#   "/>
# <polyline clip-path="url(#clip8400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   156.876,360.065 156.876,355.137
#   "/>
# <polyline clip-path="url(#clip8400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   264.445,360.065 264.445,355.137
#   "/>
# <polyline clip-path="url(#clip8400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   372.013,360.065 372.013,355.137
#   "/>
# <polyline clip-path="url(#clip8400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   479.582,360.065 479.582,355.137
#   "/>
# <polyline clip-path="url(#clip8400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   54.5598,360.065 62.4461,360.065
#   "/>
# <polyline clip-path="url(#clip8400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   54.5598,277.923 62.4461,277.923
#   "/>
# <polyline clip-path="url(#clip8400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   54.5598,195.781 62.4461,195.781
#   "/>
# <polyline clip-path="url(#clip8400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   54.5598,113.638 62.4461,113.638
#   "/>
# <polyline clip-path="url(#clip8400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   54.5598,31.4961 62.4461,31.4961
#   "/>
# <g clip-path="url(#clip8400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 156.876, 373.865)" x="156.876" y="373.865">0.2</text>
# </g>
# <g clip-path="url(#clip8400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 264.445, 373.865)" x="264.445" y="373.865">0.4</text>
# </g>
# <g clip-path="url(#clip8400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 372.013, 373.865)" x="372.013" y="373.865">0.6</text>
# </g>
# <g clip-path="url(#clip8400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 479.582, 373.865)" x="479.582" y="373.865">0.8</text>
# </g>
# <g clip-path="url(#clip8400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 48.5598, 364.565)" x="48.5598" y="364.565">1.00</text>
# </g>
# <g clip-path="url(#clip8400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 48.5598, 282.423)" x="48.5598" y="282.423">1.25</text>
# </g>
# <g clip-path="url(#clip8400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 48.5598, 200.281)" x="48.5598" y="200.281">1.50</text>
# </g>
# <g clip-path="url(#clip8400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 48.5598,
text>
# </g>
# <g clip-path="url(#clip4200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 48.5598, 137.958)" x="48.5598" y="137.958">0.25</text>
# </g>
# <g clip-path="url(#clip4200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 48.5598, 82.344)" x="48.5598" y="82.344">0.30</text>
# </g>
# <g clip-path="url(#clip4200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:21; text-anchor:middle;" transform="rotate(0, 317.437, 18)" x="317.437" y="18">Probability density function of</text>
# </g>
# <g clip-path="url(#clip4200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:21; text-anchor:middle;" transform="rotate(0, 317.437, 40.68)" x="317.437" y="40.68">Distributions.VonMises</text>
# </g>
# <g clip-path="url(#clip4200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:16; text-anchor:middle;" transform="rotate(0, 317.437, 397.6)" x="317.437" y="397.6">value of random variable</text>
# </g>
# <g clip-path="url(#clip4200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:16; text-anchor:middle;" transform="rotate(-90, 14.4, 195.781)" x="14.4" y="195.781">probability</text>
# </g>
# <polyline clip-path="url(#clip4202)" style="stroke:#009af9; stroke-width:1; stroke-opacity:1; fill:none" points="
#   54.5598,360.065 56.7962,359.993
#   "/>
# <polyline clip-path="url(#clip4202)" style="stroke:#009af9; stroke-width:1; stroke-opacity:1; fill:none" points="
#   56.7962,359.993 77.475,356.967
#   "/>
# <polyline clip-path="url(#clip4202)" style="stroke:#009af9; stroke-wi
# Could not plot the default Distributions.Univariate: ErrorException("No user recipe defined for Distributions.Univariate").
# No user recipe defined for Distributions.Univariate.
# Could not plot the default Distributions.Distribution{Distributions.Univariate,S} where S<:Distributions.ValueSupport: BoundsError(RecipesBase.RecipeData[], (1,)).
# Could not plot the default Distributions.UnivariateGMM: BoundsError(RecipesBase.RecipeData[], (1,)).
# Could not plot the default Distributions.AbstractMixtureModel{Distributions.Univariate,S,C} where C<:Distributions.Distribution where S<:Distributions.ValueSupport: BoundsError(RecipesBase.RecipeData[], (1,)).
# Could not plot the default Distributions.ValueSupport: BoundsError(RecipesBase.RecipeData[], (1,)).
# Could not plot the default Distributions.VariateForm: BoundsError(RecipesBase.RecipeData[], (1,)).
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip4400)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip4400)" points="
# 47.9701,360.065 580.315,360.065 580.315,31.4961 47.9701,31.4961
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip02">
#     <rect x="47" y="31" width="533" height="330"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip4402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   164.026,355.137 164.026,36.4246
#   "/>
# <polyline clip-path="url(#clip4402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   281.401,355.137 281.401,36.4246
#   "/>
# <polyline clip-path="url(#clip4402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   398.777,355.137 398.777,36.4246
#   "/>
# <polyline clip-path="url(#clip4402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   516.153,355.137 516.153,36.4246
#   "/>
# <polyline clip-path="url(#clip4402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   55.9553,292.887 572.33,292.887
#   "/>
# <polyline clip-path="url(#clip4402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   55.9553,225.671 572.33,225.671
#   "/>
# <polyline clip-path="url(#clip4402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   55.9553,158.455 572.33,158.455
#   "/>
# <polyline clip-path="url(#clip4402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   55.9553,91.2391 572.33,91.2391
#   "/>
# <polyline clip-path="url(#clip4400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   47.9701,360.065 580.315,360.065
#   "/>
# <polyline clip-path="url(#clip4400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   47.9701,360.065 47.9701,31.4961
#   "/>
# <polyline clip-path="url(#clip4400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   164.026,360.065 164.026,355.137
#   "/>
# <polyline clip-path="url(#clip4400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   281.401,360.065 281.401,355.137
#   "/>
# <polyline clip-path="url(#clip4400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   398.777,360.065 398.777,355.137
#   "/>
# <polyline clip-path="url(#clip4400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   516.153,360.065 516.153,355.137
#   "/>
# <polyline clip-path="url(#clip4400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   47.9701,292.887 55.9553,292.887
#   "/>
# <polyline clip-path="url(#clip4400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   47.9701,225.671 55.9553,225.671
#   "/>
# <polyline clip-path="url(#clip4400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   47.9701,158.455 55.9553,158.455
#   "/>
# <polyline clip-path="url(#clip4400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   47.9701,91.2391 55.9553,91.2391
#   "/>
# <g clip-path="url(#clip4400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 164.026, 373.865)" x="164.026" y="373.865">2</text>
# </g>
# <g clip-path="url(#clip4400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 281.401, 373.865)" x="281.401" y="373.865">4</text>
# </g>
# <g clip-path="url(#clip4400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 398.777, 373.865)" x="398.777" y="373.865">6</text>
# </g>
# <g clip-path="url(#clip4400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 516.153, 373.865)" x="516.153" y="373.865">8</text>
# </g>
# <g clip-path="url(#clip4400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 41.9701, 297.387)" x="41.9701" y="297.387">0.2</text>
# </g>
# <g clip-path="url(#clip4400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 41.9701, 230.171)" x="41.9701" y="230.171">0.4</text>
# </g>
# <g clip-path="url(#clip4400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 41.9701, 162.955)" x="41.9701" y="162.955">0.6</text>
# </g>
# <g clip-path="url(#clip4400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 41.9701, 95.7391)" x="41.9701" y="95.7391">0.8</text>
# </g>
# <g clip-path="url(#clip4400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:21; text-anchor:middle;" transform="rotate(0, 314.143, 18)" x="314.143" y="18">Probability density function of</text>
# </g>
# <g clip-path="url(#clip4400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:21; text-anchor:middle;" transform="rotate(0, 314.143, 40.68)" x="314.143" y="40.68">Distributions.Weibull</text>
# </g>
# <g clip-path="url(#clip4400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:16; text-anchor:middle;" transform="rotate(0, 314.143, 397.6)" x="314.143" y="397.6">value of random variable</text>
# </g>
# <g clip-path="url(#clip4400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:16; text-anchor:middle;" transform="rotate(-90, 14.4, 195.781)" x="14.4" y="195.781">probability</text>
# </g>
# <polyline clip-path="url(#clip4402)" style="stroke:#009af9; stroke-width:1; stroke-opacity:1; fill:none" points="
#   47.9701,31.4961 49.2898,38.8029
#   "/>
# <polyline clip-path="url(#clip4402)" style="stroke:#009af9; stroke-width:1; stroke-opacity:1; fill:none" points="
#   49.2898,38.8029 50.6095,45.9472
#   "/>
# <polyline clip-path="url(#clip4402)" style="stroke:#009af9; stroke-width:1; stroke-opacity:1; fill:none" points="
#   50.6095,45.9472 51.9292,52.9327
#   "/>
# <polyline clip-path="url(#clip4402)" style="stroke:#009af9; stroke-width:1; stroke-opacity:1; fill:none" points="
#   51.9292,52.9327 58.0304,83.2625
#   "/>
# <polyline clip-path="url(#clip4402)" style="stroke:#009af9; stroke-width:1; stroke-opacity:1; fill:none" points="
#   58.0304,83.2625 64.1316,110.598
#   "/>
# <polyline clip-path="url(#clip4402)" style="stroke:#009af9; stroke-width:1; stroke-opacity:1; fill:none" points="
#   64.1316,110.598 70.2329,135.234
#   "/>
# <polyline clip-path="url(#clip4402)" style="stroke:#009af9; stroke-width:1; stroke-opacity:1; fill:none" points="
#   70.2329,135.234 76.3341,157.437
#   "/>
# <polyline clip-path="url(#clip4402)" style="stroke:#009af9; stroke-width:1; stroke-opacity:1; fill:none" points="
#   76.3341,157.437 82.4353,177.448
#   "/>
# <polyline clip-path="url(#clip4402)" style="stroke:#009af9; stroke-width:1; stroke-opacity:1; fill:none" points="
#   82.4353,177.448 88.5365,195.483
#   "/>
# <polyline clip-path="url(#clip4402)" style="stroke:#009af9; stroke-width:1; stroke-opac
# Could not create Distributions.VonMisesFisher (1, 1): MethodError(Distributions.VonMisesFisher, (1, 1), 0x0000000000005f3a).
# Could not plot the default Distributions.WalleniusNoncentralHypergeometric: BoundsError(RecipesBase.RecipeData[], (1,)).
# Could not create Distributions.Wishart (1, 1): MethodError(Distributions.Wishart, (1, 1), 0x0000000000005f3a).
# Could not plot the default Distributions.MvNormal{Float64,PDMats.PDiagMat{Float64,Array{Float64,1}},Distributions.ZeroVector{Float64}}: BoundsError(RecipesBase.RecipeData[], (1,)).
# Could not plot the default Distributions.MvNormalCanon{Float64,PDMats.PDiagMat{Float64,Array{Float64,1}},Distributions.ZeroVector{Float64}}: BoundsError(RecipesBase.RecipeData[], (1,)).
# Could not plot the default Distributions.MvNormal{Float64,PDMats.PDMat{Float64,Array{Float64,2}},Distributions.ZeroVector{Float64}}: BoundsError(RecipesBase.RecipeData[], (1,)).
# Could not plot the default Distributions.MvNormalCanon{Float64,PDMats.PDMat{Float64,Array{Float64,2}},Distributions.ZeroVector{Float64}}: BoundsError(RecipesBase.RecipeData[], (1,)).
# Could not plot the default Distributions.MvNormal{Float64,PDMats.ScalMat{Float64},Distributions.ZeroVector{Float64}}: BoundsError(RecipesBase.RecipeData[], (1,)).
# Could not plot the default Distributions.MvNormalCanon{Float64,PDMats.ScalMat{Float64},Distributions.ZeroVector{Float64}}: BoundsError(RecipesBase.RecipeData[], (1,)).

# %%
# export this notebook as HTML to index.html
cmd = `jupyter nbconvert --to html DistributionsPlot.jl.ipynb --stdout`
run(pipeline(cmd, stdout="index.html"))

# %%
d_obj = Distributions.Gaussian(1)
d_obj

# %%
plot(d_obj,
#     title=("Probability density function of\n" * string(d_obj)),
    title="Probability density function of\n" * "Gaussian",
    xlabel="value of random variable",
    ylabel="probability",
    label="Gaussian(1)",
)
